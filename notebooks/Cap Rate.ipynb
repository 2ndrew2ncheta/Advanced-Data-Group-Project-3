# %%
import pandas as pd

# %% [markdown]
# First import acris, a DataFrame loaded with data from 2003 building sales in 2020-2022.

# %%
acris=pd.read_csv('../data/acris_sales_2020-2022.csv', converters={'bbl':str})

# %% [markdown]
# Let's see if that worked.

# %%
acris
# Out:
#              bbl   document_id  res_unit  total_units_doc  prop_units  \
# 0     2032920019  2.020080e+15        31               31         1.0
# 1     1019370046  2.020081e+15         8                8         1.0
# 2     1004350011  2.020090e+15        10               10         1.0
# 3     2039230054  2.020091e+15        17               17         1.0
# 4     1004180047  2.020092e+15        22               22         1.0
# ...          ...           ...       ...              ...         ...
# 1998  3018510021  2.021101e+15         7                7         1.0
# 1999  3078190046  2.021110e+15        83               83         1.0
# 2000  3033860058  2.021122e+15         6                6         1.0
# 2001  3023110019  2.021123e+15         5                5         1.0
# 2002  3007970022  2.021123e+15         6                6         1.0
#
#       document_amt  price_per_blgd     ppu  percent_trans  units_bought  ...  \
# 0          4950000         4950000  159677          100.0          31.0  ...
# 1           800000          800000  100000          100.0           8.0  ...
# 2          8500000         8500000  850000          100.0          10.0  ...
# 3          2200000         2200000  129412          100.0          17.0  ...
# 4          5350000         5350000  243182          100.0          22.0  ...
# ...            ...             ...     ...            ...           ...  ...
# 1998       1050000         1050000  150000          100.0           7.0  ...
# 1999       6733800         6733800   81130           60.0          49.8  ...
# 2000        975000          975000  162500          100.0           6.0  ...
# 2001       4000000         4000000  800000          100.0           5.0  ...
# 2002        412500          412500   68750           50.0           3.0  ...
#
#       z_percent_trans_ppu boro  year  p1_count  \
# 0                  -0.206    2  2020         1
# 1                  -0.707    1  2020         2
# 2                   0.815    1  2020         1
# 3                  -0.567    2  2020         1
# 4                  -0.417    1  2020         1
# ...                   ...  ...   ...       ...
# 1998               -0.824    3  2021        11
# 1999               -0.885    3  2021         1
# 2000               -0.772    3  2021         2
# 2001                1.862    3  2021         1
# 2002               -0.875    3  2021         2
#
#                              p1_a_name                   p1_a_address_1  \
# 0                       2968 PERRY LLC            C/O: THE MORGAN GROUP
# 1       RONALD ADAMS, AS ADMINISTRATOR                   234 W 132ND ST
# 2                      94 ST MARKS LLC          C/O: PENN SOUTH CAPITAL
# 3               1532 LELAND AVENUE INC  35 E GRASSY SPRAIN RD, STE. 400
# 4                     109 ELDRIDGE LLC                C/O KOSSOFF, PLLC
# ...                                ...                              ...
# 1998                GROSVENOR, FELICIA             82 MACDONOUGH STREET
# 1999  FRED & IVAN LEIST SPECIAL K, LLC              1710 CORTELYOU ROAD
# 2000             CHIAFFITELLI, NANCY B            1517 JEFFERSON AVENUE
# 2001  THE NORTH NINTH STREET GROUP LLC                164 CLYMER STREET
# 2002                 FERNANDEZ, LUIS M                  446 46TH STREET
#
#                         p1_a_address_2  p1_a_city p1_a_state   p1_a_zip
# 0     ONE SOUND SHORE DRIVE, SUITE 203  GREENWICH         CT       6830
# 1                                  NaN   NEW YORK         NY  100277804
# 2           41 MADISON AVE, 31ST FLOOR   NEW YORK         NY      10010
# 3          C/O VINCENT CASTELLANO, ESQ    YONKERS         NY      10710
# 4              217 BROADWAY, SUITE 401   NEW YORK         NY      10007
# ...                                ...        ...        ...        ...
# 1998                               NaN   BROOKLYN         NY  112162205
# 1999                               NaN   BROOKLYN         NY      11226
# 2000                               NaN   BROOKLYN         NY      11237
# 2001                               NaN   BROOKLYN         NY      11211
# 2002                               NaN   BROOKLYN         NY      11220
#
# [2003 rows x 23 columns]

# %% [markdown]
# Now we'll import another dataframe called taxform, reflecting the amended tax statements from 26886 building owners in 2021.

# %%
taxform=pd.read_csv('../data/file_201_data_sm_tract.csv')

# %%
taxform
# Out:
#        BORO  BLOCK  FROM_LOT  TO_LOT  FILING YEAR  REGULATED  UNREGULATED  \
# 0         1    447        25     NaN         2021     3674.0          NaN
# 1         1   1079        61     NaN         2021        NaN          NaN
# 2         1   1000        29     NaN         2021        NaN          NaN
# 3         1   1000        61     NaN         2021        NaN          NaN
# 4         1   1001      1001  1001.0         2021        NaN          NaN
# ...     ...    ...       ...     ...          ...        ...          ...
# 26881     5   3960        65     NaN         2021        NaN          NaN
# 26882     5   3960         7     NaN         2021        NaN          NaN
# 26883     5   3960        61     NaN         2021        NaN          NaN
# 26884     5   3960        65     NaN         2021        NaN          NaN
# 26885     5   7206       314     NaN         2021        NaN          NaN
#
#             OFFICE  OWNER/RELATED SPACE  GOV. RENTAL SUBSIDIES  \
# 0              NaN                  NaN                    NaN
# 1              NaN                  NaN                    NaN
# 2      129305065.0                  NaN                    NaN
# 3              NaN                  NaN               714647.0
# 4              NaN                  NaN                    NaN
# ...            ...                  ...                    ...
# 26881          NaN                  NaN                    NaN
# 26882          NaN                  NaN                    NaN
# 26883          NaN                  NaN                    NaN
# 26884          NaN                  NaN                    NaN
# 26885          NaN                  NaN                    NaN
#
#        TOTAL INCOME FROM REAL ESTATE  TOTAL EXPENSES  \
# 0                            93074.0         96825.0
# 1                           295046.0         15020.0
# 2                        159048807.0      39952316.0
# 3                           714647.0       1236523.0
# 4                          3625614.0        296800.0
# ...                              ...             ...
# 26881                      2274290.0        659462.0
# 26882                      2274290.0        659462.0
# 26883                      2274290.0        659462.0
# 26884                      2274290.0        659462.0
# 26885                       210000.0        151896.0
#
#        AMORTIZED LEASE AND TENANT IMP. COSTS  REPAIRS AND MAINT.  tract_10
# 0                                        NaN             28456.0       NaN
# 1                                        NaN              7709.0       NaN
# 2                                 11508372.0           5936267.0       NaN
# 3                                        NaN             62443.0       NaN
# 4                                    76509.0              7819.0       NaN
# ...                                      ...                 ...       ...
# 26881                                59866.0            242514.0       NaN
# 26882                                59866.0            242514.0       NaN
# 26883                                59866.0            242514.0       NaN
# 26884                                59866.0            242514.0       NaN
# 26885                                    NaN                 NaN       NaN
#
# [26886 rows x 15 columns]

# %%
taxdata=pd.DataFrame(taxform)

# %%
taxdata.dtypes
# Out:
# BORO                                       int64
# BLOCK                                      int64
# FROM_LOT                                   int64
# TO_LOT                                   float64
# FILING YEAR                                int64
# REGULATED                                float64
# UNREGULATED                              float64
# OFFICE                                   float64
# OWNER/RELATED SPACE                      float64
# GOV. RENTAL SUBSIDIES                    float64
# TOTAL INCOME FROM REAL ESTATE            float64
# TOTAL EXPENSES                           float64
# AMORTIZED LEASE AND TENANT IMP. COSTS    float64
# REPAIRS AND MAINT.                       float64
# tract_10                                 float64
# dtype: object

# %% [markdown]
# Next we'll import a DataFrame called taxdata, reflecting the amended tax statements from 26886 building owners in 2021.

# %%
taxdata=pd.read_csv('../data/file_201_data_sm_tract.csv', converters={'BORO':str, 'BLOCK':str,'FROM_LOT':str})

# %%
taxdata
# Out:
#       BORO  BLOCK FROM_LOT  TO_LOT  FILING YEAR  REGULATED  UNREGULATED  \
# 0        1  00447     0025     NaN         2021     3674.0          NaN
# 1        1  01079     0061     NaN         2021        NaN          NaN
# 2        1  01000     0029     NaN         2021        NaN          NaN
# 3        1  01000     0061     NaN         2021        NaN          NaN
# 4        1  01001     1001  1001.0         2021        NaN          NaN
# ...    ...    ...      ...     ...          ...        ...          ...
# 26881    5  03960     0065     NaN         2021        NaN          NaN
# 26882    5  03960     0007     NaN         2021        NaN          NaN
# 26883    5  03960     0061     NaN         2021        NaN          NaN
# 26884    5  03960     0065     NaN         2021        NaN          NaN
# 26885    5  07206     0314     NaN         2021        NaN          NaN
#
#             OFFICE  OWNER/RELATED SPACE  GOV. RENTAL SUBSIDIES  \
# 0              NaN                  NaN                    NaN
# 1              NaN                  NaN                    NaN
# 2      129305065.0                  NaN                    NaN
# 3              NaN                  NaN               714647.0
# 4              NaN                  NaN                    NaN
# ...            ...                  ...                    ...
# 26881          NaN                  NaN                    NaN
# 26882          NaN                  NaN                    NaN
# 26883          NaN                  NaN                    NaN
# 26884          NaN                  NaN                    NaN
# 26885          NaN                  NaN                    NaN
#
#        TOTAL INCOME FROM REAL ESTATE  TOTAL EXPENSES  \
# 0                            93074.0         96825.0
# 1                           295046.0         15020.0
# 2                        159048807.0      39952316.0
# 3                           714647.0       1236523.0
# 4                          3625614.0        296800.0
# ...                              ...             ...
# 26881                      2274290.0        659462.0
# 26882                      2274290.0        659462.0
# 26883                      2274290.0        659462.0
# 26884                      2274290.0        659462.0
# 26885                       210000.0        151896.0
#
#        AMORTIZED LEASE AND TENANT IMP. COSTS  REPAIRS AND MAINT.  tract_10
# 0                                        NaN             28456.0       NaN
# 1                                        NaN              7709.0       NaN
# 2                                 11508372.0           5936267.0       NaN
# 3                                        NaN             62443.0       NaN
# 4                                    76509.0              7819.0       NaN
# ...                                      ...                 ...       ...
# 26881                                59866.0            242514.0       NaN
# 26882                                59866.0            242514.0       NaN
# 26883                                59866.0            242514.0       NaN
# 26884                                59866.0            242514.0       NaN
# 26885                                    NaN                 NaN       NaN
#
# [26886 rows x 15 columns]

# %% [markdown]
# There's no column for bbl here. We will construct one by combining the entries for boro, block and lot.

# %%
taxdata['bbl']= taxdata['BORO'].map(str)+taxdata['BLOCK'].map(str)+taxdata['FROM_LOT'].map(str)

# %%
print(taxdata['bbl'])
# Out:
# 0        1004470025
# 1        1010790061
# 2        1010000029
# 3        1010000061
# 4        1010011001
#             ...
# 26881    5039600065
# 26882    5039600007
# 26883    5039600061
# 26884    5039600065
# 26885    5072060314
# Name: bbl, Length: 26886, dtype: object

# %% [markdown]
# Next, create a another data frame called mergedata. This will combine columns from taxdata and acriss, based on the shared values in the bbl column

# %%
mergedata=pd.merge( acris, 
                    taxdata,
                    on='bbl',
                    how='inner')

# %%
mergedata
# Out:
#             bbl   document_id  res_unit  total_units_doc  prop_units  \
# 0    1004350011  2.020090e+15        10               10         1.0
# 1    1004180047  2.020092e+15        22               22         1.0
# 2    2028970127  2.020101e+15        46               46         1.0
# 3    4006330078  2.020101e+15        60               60         1.0
# 4    3012190056  2.020101e+15        21               21         1.0
# ..          ...           ...       ...              ...         ...
# 254  3007480057  2.020012e+15        17               17         1.0
# 255  1015710002  2.020012e+15        13               13         1.0
# 256  2030500070  2.020013e+15        89               89         1.0
# 257  1012020019  2.020013e+15         6                6         1.0
# 258  1019400055  2.020013e+15        17               17         1.0
#
#      document_amt  price_per_blgd     ppu  percent_trans  units_bought  ...  \
# 0         8500000         8500000  850000         100.00       10.0000  ...
# 1         5350000         5350000  243182         100.00       22.0000  ...
# 2         5000000         5000000  108696         100.00       46.0000  ...
# 3        15600000        15600000  260000         100.00       60.0000  ...
# 4         4330000         4330000  206190         100.00       21.0000  ...
# ..            ...             ...     ...            ...           ...  ...
# 254       3500000         3500000  205882         100.00       17.0000  ...
# 255        617310          617310   47485          21.66        2.8158  ...
# 256       4463828         4463828   50155         100.00       89.0000  ...
# 257       5595000         5595000  932500         100.00        6.0000  ...
# 258       2750000         2750000  161765         100.00       17.0000  ...
#
#      REGULATED UNREGULATED   OFFICE  OWNER/RELATED SPACE  \
# 0          NaN    163371.0      NaN                  NaN
# 1     119722.0    166891.0      NaN                  NaN
# 2     480401.0         NaN      NaN                  NaN
# 3     455811.0    629454.0      NaN                  NaN
# 4     157583.0    229092.0      NaN                  NaN
# ..         ...         ...      ...                  ...
# 254   257008.0         NaN      NaN                  NaN
# 255        NaN    117154.0      NaN                  NaN
# 256  1043885.0         NaN      NaN                  NaN
# 257        NaN         NaN  24000.0                  NaN
# 258   227641.0     37640.0      NaN                  NaN
#
#      GOV. RENTAL SUBSIDIES  TOTAL INCOME FROM REAL ESTATE  TOTAL EXPENSES  \
# 0                      NaN                       371827.0        604802.0
# 1                      NaN                       367698.0        195124.0
# 2                  29542.0                       509943.0        327277.0
# 3                      NaN                      1087015.0             NaN
# 4                      NaN                       393020.0        172158.0
# ..                     ...                            ...             ...
# 254                    NaN                       257008.0         85080.0
# 255                    NaN                       218174.0        147250.0
# 256                    NaN                      1058405.0        588764.0
# 257                    NaN                        24000.0         52661.0
# 258                    NaN                       265281.0        149329.0
#
#     AMORTIZED LEASE AND TENANT IMP. COSTS REPAIRS AND MAINT.      tract_10
# 0                                     NaN           181512.0           NaN
# 1                                 18753.0            45560.0           NaN
# 2                                     NaN            65749.0  3.600502e+10
# 3                                     NaN            66790.0           NaN
# 4                                 11667.0            75127.0           NaN
# ..                                    ...                ...           ...
# 254                                   NaN            19187.0           NaN
# 255                                   NaN            60873.0           NaN
# 256                                   NaN           102631.0  3.600504e+10
# 257                                   NaN             7159.0           NaN
# 258                               43281.0            18358.0           NaN
#
# [259 rows x 38 columns]

# %% [markdown]
# Next, we create a new column in the mergedata sheet called cap rate, populated using the formula CR= (income-expenses)/(sale price)

# %%
mergedata['cap rate']=100*(mergedata['TOTAL INCOME FROM REAL ESTATE']-mergedata['TOTAL EXPENSES'])/mergedata['price_per_blgd']

# %%
mergedata
# Out:
#             bbl   document_id  res_unit  total_units_doc  prop_units  \
# 0    1004350011  2.020090e+15        10               10         1.0
# 1    1004180047  2.020092e+15        22               22         1.0
# 2    2028970127  2.020101e+15        46               46         1.0
# 3    4006330078  2.020101e+15        60               60         1.0
# 4    3012190056  2.020101e+15        21               21         1.0
# ..          ...           ...       ...              ...         ...
# 254  3007480057  2.020012e+15        17               17         1.0
# 255  1015710002  2.020012e+15        13               13         1.0
# 256  2030500070  2.020013e+15        89               89         1.0
# 257  1012020019  2.020013e+15         6                6         1.0
# 258  1019400055  2.020013e+15        17               17         1.0
#
#      document_amt  price_per_blgd     ppu  percent_trans  units_bought  ...  \
# 0         8500000         8500000  850000         100.00       10.0000  ...
# 1         5350000         5350000  243182         100.00       22.0000  ...
# 2         5000000         5000000  108696         100.00       46.0000  ...
# 3        15600000        15600000  260000         100.00       60.0000  ...
# 4         4330000         4330000  206190         100.00       21.0000  ...
# ..            ...             ...     ...            ...           ...  ...
# 254       3500000         3500000  205882         100.00       17.0000  ...
# 255        617310          617310   47485          21.66        2.8158  ...
# 256       4463828         4463828   50155         100.00       89.0000  ...
# 257       5595000         5595000  932500         100.00        6.0000  ...
# 258       2750000         2750000  161765         100.00       17.0000  ...
#
#      UNREGULATED   OFFICE  OWNER/RELATED SPACE  GOV. RENTAL SUBSIDIES  \
# 0       163371.0      NaN                  NaN                    NaN
# 1       166891.0      NaN                  NaN                    NaN
# 2            NaN      NaN                  NaN                29542.0
# 3       629454.0      NaN                  NaN                    NaN
# 4       229092.0      NaN                  NaN                    NaN
# ..           ...      ...                  ...                    ...
# 254          NaN      NaN                  NaN                    NaN
# 255     117154.0      NaN                  NaN                    NaN
# 256          NaN      NaN                  NaN                    NaN
# 257          NaN  24000.0                  NaN                    NaN
# 258      37640.0      NaN                  NaN                    NaN
#
#      TOTAL INCOME FROM REAL ESTATE  TOTAL EXPENSES  \
# 0                         371827.0        604802.0
# 1                         367698.0        195124.0
# 2                         509943.0        327277.0
# 3                        1087015.0             NaN
# 4                         393020.0        172158.0
# ..                             ...             ...
# 254                       257008.0         85080.0
# 255                       218174.0        147250.0
# 256                      1058405.0        588764.0
# 257                        24000.0         52661.0
# 258                       265281.0        149329.0
#
#      AMORTIZED LEASE AND TENANT IMP. COSTS REPAIRS AND MAINT.      tract_10  \
# 0                                      NaN           181512.0           NaN
# 1                                  18753.0            45560.0           NaN
# 2                                      NaN            65749.0  3.600502e+10
# 3                                      NaN            66790.0           NaN
# 4                                  11667.0            75127.0           NaN
# ..                                     ...                ...           ...
# 254                                    NaN            19187.0           NaN
# 255                                    NaN            60873.0           NaN
# 256                                    NaN           102631.0  3.600504e+10
# 257                                    NaN             7159.0           NaN
# 258                                43281.0            18358.0           NaN
#
#       cap rate
# 0    -2.740882
# 1     3.225682
# 2     3.653320
# 3          NaN
# 4     5.100739
# ..         ...
# 254   4.912229
# 255  11.489203
# 256  10.521037
# 257  -0.512261
# 258   4.216436
#
# [259 rows x 39 columns]

# %% [markdown]
# Finally, we export the frame mergedata to a new spreadsheet in the output folder called CapRates.csv

# %%
mergedata.to_csv('../output/CapRates.csv')
